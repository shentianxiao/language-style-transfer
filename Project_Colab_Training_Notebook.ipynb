# %%
# !git clone https://github.com/why-2004/language-style-transfer.git
# %cd language-style-transfer
# %mkdir tmp
# %cd code
# Out:
# fatal: destination path 'language-style-transfer' already exists and is not an empty directory.
# /content/language-style-transfer
# mkdir: cannot create directory ‘tmp’: File exists
# /content/language-style-transfer/code

# %%
# !pip install ipdb

# %%
#%tensorflow_version 1.x

# %%
#!pip install tf-nightly

# %%
# !python style_transfer.py --train ../data/subj_dataset/obj.train --dev ../data/subj_dataset/obj.dev --output ../tmp/obj.dev --vocab ../tmp/subj_dataset.vocab --model ../tmp/model
# Out:
# 2021-04-06 07:47:41.890913: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ------------------------------------------------
# {   'batch_size': 64,
#     'beam': 1,
#     'dev': '../data/subj_dataset/obj.dev',
#     'dim_emb': 100,
#     'dim_y': 200,
#     'dim_z': 500,
#     'dropout_keep_prob': 0.5,
#     'embedding': '',
#     'filter_sizes': '1,2,3,4,5',
#     'gamma_decay': 1,
#     'gamma_init': 0.1,
#     'gamma_min': 0.1,
#     'learning_rate': 0.0005,
#     'load_model': False,
#     'max_epochs': 20,
#     'max_seq_length': 20,
#     'max_train_size': -1,
#     'model': '../tmp/model',
#     'n_filters': 128,
#     'n_layers': 1,
#     'online_testing': False,
#     'output': '../tmp/obj.dev',
#     'rho': 1,
#     'steps_per_checkpoint': 1000,
#     'test': '',
#     'train': '../data/subj_dataset/obj.train',
#     'vocab': '../tmp/subj_dataset.vocab'}
# ...

# %%
#!zip -r language.zip language-style-transfer/

# %%
'''from google.colab import files
from google.colab import auth
from googleapiclient.http import MediaFileUpload
from googleapiclient.discovery import build

auth.authenticate_user()
drive_service = build('drive', 'v3')

def save_file_to_drive(name, path):
    file_metadata = {
    'name': name,
    'mimeType': 'application/octet-stream'
    }

    media = MediaFileUpload(path, 
                  mimetype='application/octet-stream',
                  resumable=True)

    created = drive_service.files().create(body=file_metadata, media_body=media, fields='id').execute()

    print('File ID: {}'.format(created.get('id')))

    return created
save_file_to_drive("language.zip", "/content/language.zip")'''
